# %% [markdown]
# # Testing confidence intervals
# Author: Aleksander Filip Żarnecki (University of Warsaw)

# %% [markdown]
# ### (0) Import libraries

# %%
import math
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### (1) Definition of random number generation and limits

# %%
# Parameters of the Gamma distribution

mean = 10
sigma = np.sqrt(10.0)

k = (mean / sigma) ** 2

lam = sigma**2 / mean

# Considered limits

limlow = np.array(
    [
        mean - sigma,
        mean - 2 * sigma,
        mean - 3 * sigma,
        mean - 4 * sigma,
        mean - 5 * sigma,
    ]
)
limhig = np.array(
    [
        mean + sigma,
        mean + 2 * sigma,
        mean + 3 * sigma,
        mean + 4 * sigma,
        mean + 5 * sigma,
    ]
)

# Number generation procedure


def myrnd(N=1):
    rvec = np.random.gamma(k, scale=lam, size=(N))

    return rvec

# %% [markdown]
# ### (2) Generate multiple numbers

# %%
Nmc = 100000000

rvec = myrnd(Nmc)

# %% [markdown]
# ### (3)  Count limit probability

# %%
print("\nLower limit probability:")

for ll in limlow:
    nl = np.sum(rvec < ll)
    p = nl / Nmc
    ep = np.sqrt(p * (1 - p) / Nmc)
    print(" P ( x < ", ll, ") = ", p, " +/- ", ep)

print("\nUpper limit probability:")

for ul in limhig:
    nl = np.sum(rvec > ul)
    p = nl / Nmc
    ep = np.sqrt(p * (1 - p) / Nmc)
    print(" P ( x > ", ul, ") = ", p, " +/- ", ep)
# Out:
# Lower limit probability:
#  P ( x <  6.83772233983162 ) =  0.1534502  +/-  3.604209152088153e-05
#  P ( x <  3.675444679663241 ) =  0.00463459  +/-  6.791988350646591e-06
#  P ( x <  0.5131670194948619 ) =  0.0  +/-  0.0
#  P ( x <  -2.649110640673518 ) =  0.0  +/-  0.0
#  P ( x <  -5.811388300841898 ) =  0.0  +/-  0.0
#
# Upper limit probability:
#  P ( x >  13.16227766016838 ) =  0.15530706  +/-  3.6219715227229e-05
#  P ( x >  16.32455532033676 ) =  0.03683681  +/-  1.8836098170540494e-05
#  P ( x >  19.486832980505138 ) =  0.00672108  +/-  8.170622426494568e-06
#  P ( x >  22.64911064067352 ) =  0.00100467  +/-  3.168060350105566e-06
#  P ( x >  25.811388300841898 ) =  0.0001307  +/-  1.1431662937210842e-06

# %% [markdown]
# ### (4) Plot distribution histogram

# %%
# Range for result histogram

Xmax = 40.0
Nbin = 100

# Plot histogram

plt.figure(figsize=(9, 6))

plt.hist(
    rvec,
    bins=Nbin,
    range=[0.0, Xmax],
    density=True,
    log=True,
    histtype="step",
    linewidth=3,
)

plt.title("Probability distribution from MC", size=24)
plt.xlabel("variable", size=24)
plt.ylabel("Probability density", size=24)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.xlim([0.0, Xmax])
plt.grid(which="major", axis="both")

fname = "06_interval_3.png"
plt.savefig(fname)

plt.show()
